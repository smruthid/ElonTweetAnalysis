# %%
pip install textblob
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pathlib import Path
from textblob import TextBlob

# %%
kaggle_df = pd.read_csv(
    Path("KaggleData/TweetsElonMusk.csv"),
    index_col='date',
    parse_dates=True,
    infer_datetime_format=True
)
kaggle_df = kaggle_df[['username', 'tweet']]
kaggle_df.head(10)
# Out:
#             username                                              tweet
# date
# 2021-04-11  elonmusk  @vincent13031925 For now. Costs are decreasing...
# 2021-04-11  elonmusk                           Love this beautiful shot
# 2021-04-11  elonmusk  @agnostoxxx @CathieDWood @ARKInvest Trust the ...
# 2021-04-11  elonmusk                 The art In Cyberpunk is incredible
# 2021-04-11  elonmusk                                    @itsALLrisky 🤣🤣
# 2021-04-11  elonmusk             @seinfeldguru @WholeMarsBlog Nope haha
# 2021-04-11  elonmusk  @WholeMarsBlog If you don’t say anything &amp;...
# 2021-04-11  elonmusk  @DeltavPhotos @PortCanaveral That rocket is a ...
# 2021-04-11  elonmusk               Blimps rock  https://t.co/e8cu5FkNOI
# 2021-04-10  elonmusk  @engineers_feed Due to lower gravity, you can ...

# %%
def subjectivity_sentiment_score(tweet):
    return TextBlob(tweet).sentiment.subjectivity

def polarity_sentiment_score(tweet):
    return TextBlob(tweet).sentiment.polarity

kaggle_df['subjectivity'] = kaggle_df['tweet'].apply(subjectivity_sentiment_score)
kaggle_df['polarity'] = kaggle_df['tweet'].apply(polarity_sentiment_score)

# %%
kaggle_df.head(20)
# Out:
#             username                                              tweet  \
# date
# 2021-04-11  elonmusk  @vincent13031925 For now. Costs are decreasing...
# 2021-04-11  elonmusk                           Love this beautiful shot
# 2021-04-11  elonmusk  @agnostoxxx @CathieDWood @ARKInvest Trust the ...
# 2021-04-11  elonmusk                 The art In Cyberpunk is incredible
# 2021-04-11  elonmusk                                    @itsALLrisky 🤣🤣
# 2021-04-11  elonmusk             @seinfeldguru @WholeMarsBlog Nope haha
# 2021-04-11  elonmusk  @WholeMarsBlog If you don’t say anything &amp;...
# 2021-04-11  elonmusk  @DeltavPhotos @PortCanaveral That rocket is a ...
# 2021-04-11  elonmusk               Blimps rock  https://t.co/e8cu5FkNOI
# 2021-04-10  elonmusk  @engineers_feed Due to lower gravity, you can ...
# 2021-04-10  elonmusk                            @DrPhiltill Good thread
# 2021-04-10  elonmusk                           @alexellisuk Pretty much
# ...
